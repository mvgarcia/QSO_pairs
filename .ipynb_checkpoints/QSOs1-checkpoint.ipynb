# %%
import fitsio
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from time import time

# %%
targets_path = "/global/cfs/projectdirs/desi/target/catalogs/dr8/0.42.0/targets/main/resolve/dark"
filename = os.path.join(targets_path, "targets-dark-hp-9.fits")


columns = ['TARGETID', 'DESI_TARGET', 'MWS_TARGET', 
           'BGS_TARGET', 'SUBPRIORITY', 'NUMOBS_INIT', 
           'PRIORITY_INIT', 'RA', 'DEC', 'HPXPIXEL', 
           'BRICKNAME', 'FLUX_R', 'FLUX_G', 'FLUX_Z',
           'MW_TRANSMISSION_G','MW_TRANSMISSION_R', 'MW_TRANSMISSION_Z']
filein = fitsio.FITS(filename)
data = filein[1].read(columns=columns)

# %%
len(data)
# Out:
# 3416317

# %%
"""r = np.random.random(len(data))
rr = r<0.1"""
plt.scatter(data['RA'], data['DEC'], s=0.5)
#print(len(data[rr]))

# %%
is_qso = (data['DESI_TARGET'] & 4)!=0
data_qso = data[is_qso]
print(len(data_qso))
plt.scatter(data_qso['RA'], data_qso['DEC'])
# Out:
# 240488

# %%
print(data_qso['RA'], data_qso['DEC'])
ra=np.deg2rad(data_qso['RA'])
dec=np.deg2rad(data_qso['DEC'])
"""def distancia (ra1,ra2,dec1,dec2):
    rad=np.arccos((np.sin(dec1)*np.sin(dec2))+(np.cos(dec1)*np.cos(dec2)*np.cos(ra1-ra2)))
    arcsec=np.rad2deg(rad)*60*60
    return arcsec"""
def distancia(ra1,dec1,raArray, decArray):
    rad=np.arccos(np.around(((np.sin(dec1)*np.sin(decArray))+(np.cos(dec1)*np.cos(decArray)*np.cos(ra1-raArray))),10))
    arcsec=np.rad2deg(rad)*60*60
    return arcsec
# Out:
# [237.08797733 237.21258466 236.98399488 ... 253.81149474 254.04565214
#  253.91558514] [52.12518625 52.13180324 52.15112396 ... 44.57933158 44.58277424
#  44.58321199]

# %%
"""indexes=[]
for i in range(1000):
    for j in range(i+1,len(dec)):
        dist=distancia(ra[i],ra[j],dec[i],dec[j])
        if(dist<10):
            indexes.append([i,j])
print(len(indexes),indexes)"""

# %%
dist_min=[]
ti=time()
for i in range(1000):
    dist=np.sort(distancia(ra[i],dec[i],ra,dec))[1]
    dist_min.append(dist)
    
dist_min=np.array(dist_min)
dist_min[dist_min<10]
tf=time()
tiempo=tf-ti
print(tiempo)
# Out:
# array([8.25059202, 8.25059202, 5.05243548, 5.05243548, 6.52266616,
#        6.52266616, 9.22444243, 9.22444243])

# %%
dist_min=[]
indexes=[]
ti=time()
for i in range(1000):
    dist=distancia(ra[i],dec[i],ra,dec)
    dist=dist[dist<10]
    dist=dist[dist!=0]
    indexes.append([ra,dec,ra[dist!=0],dec[dist!=0]])
    dist_min=np.append(dist_min, dist)
dist_min=list(set(dist_min))
tf=time()
tiempo=tf-ti
print(tiempo)
# Out:
# 17.899325609207153

# %%
dist_min
# Out:
# array([8.25059202, 5.05243548, 6.52266616, 9.22444243])

# %%
dist_min=np.array([2,2,3,3,4,4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-0bf210279c4e> in <module>
#       1 dist_min=np.array([2,2,3,3,4,4])
# ----> 2 ra[dist_min<3]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 240488 but corresponding boolean dimension is 6

# %%
plt.hist(dist_min)
dist_min=np.array(dist_min)
print(len(dist_min[dist_min<10]))
# Out:
# 4

# %%
a=indexes
col=matplotlib.colors.Colormap('Rainbow')
print(col)
for index in range(len(a)):
    for k in a[index]:
        #rgb=([index*0.1,index*0.1,index*0.1])
        plt.scatter(ra[k],dec[k],cmap=col,s=2)
# Out:
# <matplotlib.colors.Colormap object at 0x2aaad6442fa0>
